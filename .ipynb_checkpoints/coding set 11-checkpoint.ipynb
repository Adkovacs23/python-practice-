# %% [markdown]
# # coding set 11

# %% [markdown]
# ### programming problem 2, shift supervisor class

# %% [markdown]
# this problem wants us to In a particular factory, a shift supervisor is a salaried employee who supervises a shift. In addition to a salary, the shift supervisor earns a yearly bonus when his or her shift meets production goals. Write a  class that is a subclass of the  class you created in Programming Exercise 1. The  class should keep a data attribute for the annual salary, and a data attribute for the annual production bonus that a shift supervisor has earned. Demonstrate the class by writing a program that uses a  object.

# %%
class Employee:
    def __init__(self, name="", number=0):
        self.__name = name
        self.__number = number

    # Accessor methods
    def get_name(self):
        return self.__name

    def get_number(self):
        return self.__number

    # Mutator methods
    def set_name(self, name):
        self.__name = name

    def set_number(self, number):
        self.__number = number

class ShiftEmployee(Employee):
    def __init__(self, name="", number=0, shift=1, hourly_pay_rate=0.0):
        super().__init__(name, number)
        self.__shift = shift
        self.__hourly_pay_rate = hourly_pay_rate

    # Accessor methods
    def get_shift(self):
        return self.__shift

    def get_hourly_pay_rate(self):
        return self.__hourly_pay_rate

    # Mutator methods
    def set_shift(self, shift):
        if shift in [1, 2]:  # Ensure shift is either 1 (day) or 2 (night)
            self.__shift = shift
        else:
            raise ValueError("Shift must be 1 (day) or 2 (night)")

    def set_hourly_pay_rate(self, hourly_pay_rate):
        self.__hourly_pay_rate = hourly_pay_rate

class ShiftSupervisor(ShiftEmployee):
    def __init__(self, name="", number=0, shift=1, hourly_pay_rate=0.0, annual_salary=0.0, annual_bonus=0.0):
        super().__init__(name, number, shift, hourly_pay_rate)
        self.__annual_salary = annual_salary
        self.__annual_bonus = annual_bonus

    # Accessor methods
    def get_annual_salary(self):
        return self.__annual_salary

    def get_annual_bonus(self):
        return self.__annual_bonus

    # Mutator methods
    def set_annual_salary(self, annual_salary):
        self.__annual_salary = annual_salary

    def set_annual_bonus(self, annual_bonus):
        self.__annual_bonus = annual_bonus

# Program to create a ShiftSupervisor object and prompt user for data
def main():
    name = input("Enter the supervisor's name: ")
    number = int(input("Enter the supervisor's number: "))
    shift = int(input("Enter the shift number (1 for day, 2 for night): "))
    hourly_pay_rate = float(input("Enter the hourly pay rate: "))
    annual_salary = float(input("Enter the annual salary: "))
    annual_bonus = float(input("Enter the annual production bonus: "))

    # Create ShiftSupervisor object
    shift_supervisor = ShiftSupervisor(name, number, shift, hourly_pay_rate, annual_salary, annual_bonus)

    # Display the entered data
    print("\nShift Supervisor Details:")
    print(f"Name: {shift_supervisor.get_name()}")
    print(f"Number: {shift_supervisor.get_number()}")
    print(f"Shift: {shift_supervisor.get_shift()}")
    print(f"Hourly Pay Rate: {shift_supervisor.get_hourly_pay_rate()}")
    print(f"Annual Salary: {shift_supervisor.get_annual_salary()}")
    print(f"Annual Production Bonus: {shift_supervisor.get_annual_bonus()}")

if __name__ == "__main__":
    main()
# Out:
# Enter the supervisor's name: bob
# Enter the supervisor's number: 1234
# Enter the shift number (1 for day, 2 for night): 1
# Enter the hourly pay rate: 50
# Enter the annual salary: 100000
# Enter the annual production bonus: 10000
#
# Shift Supervisor Details:
# Name: bob
# Number: 1234
# Shift: 1
# Hourly Pay Rate: 50.0
# Annual Salary: 100000.0
# Annual Production Bonus: 10000.0

# %% [markdown]
# here is a flowchart for that work
# +--------------------------+
# |         Start            |
# +--------------------------+
#            |
#            v
# +--------------------------+
# |   Input Supervisor Data  |
# | - Name                   |
# | - Number                 |
# | - Shift (1 for day,      |
# |   2 for night)           |
# | - Hourly Pay Rate        |
# | - Annual Salary          |
# | - Annual Bonus           |
# +--------------------------+
#            |
#            v
# +--------------------------+
# | Create ShiftSupervisor   |
# | Object with Input Data   |
# +--------------------------+       |
#            v
# +--------------------------+
# |    Display Supervisor    |
# |         Details          |
# | - Name                   |
# | - Number                 |
# | - Shift                  |
# | - Hourly Pay Rate        |
# | - Annual Salary          |
# | - Annual Bonus           |
# +--------------------------+
#            |
#            v
# +--------------------------+
# |           End            |
# +--------------------------+

# %% [markdown]
# ### programming problem 3

# %% [markdown]
# this problem wants us to Write a class named  with data attributes for a person’s name, address, and telephone number. Next, write a class named  that is a subclass of the  class. The  class should have a data attribute for a customer number, and a Boolean data attribute indicating whether the customer wishes to be on a mailing list. Demonstrate an instance of the  class in a simple program.

# %%
class Person:
    def __init__(self, name="", address="", telephone=""):
        self.__name = name
        self.__address = address
        self.__telephone = telephone

    # Accessor methods
    def get_name(self):
        return self.__name

    def get_address(self):
        return self.__address

    def get_telephone(self):
        return self.__telephone

    # Mutator methods
    def set_name(self, name):
        self.__name = name

    def set_address(self, address):
        self.__address = address

    def set_telephone(self, telephone):
        self.__telephone = telephone

class Customer(Person):
    def __init__(self, name="", address="", telephone="", customer_number=0, on_mailing_list=False):
        super().__init__(name, address, telephone)
        self.__customer_number = customer_number
        self.__on_mailing_list = on_mailing_list

    # Accessor methods
    def get_customer_number(self):
        return self.__customer_number

    def get_on_mailing_list(self):
        return self.__on_mailing_list

    # Mutator methods
    def set_customer_number(self, customer_number):
        self.__customer_number = customer_number

    def set_on_mailing_list(self, on_mailing_list):
        self.__on_mailing_list = on_mailing_list

# Program to create a Customer object and prompt user for data
def main():
    name = input("Enter the customer's name: ")
    address = input("Enter the customer's address: ")
    telephone = input("Enter the customer's telephone number: ")
    customer_number = int(input("Enter the customer number: "))
    on_mailing_list_input = input("Does the customer wish to be on the mailing list? (yes/no): ")
    on_mailing_list = on_mailing_list_input.lower() == 'yes'

    # Create Customer object
    customer = Customer(name, address, telephone, customer_number, on_mailing_list)

    # Display the entered data
    print("\nCustomer Details:")
    print(f"Name: {customer.get_name()}")
    print(f"Address: {customer.get_address()}")
    print(f"Telephone: {customer.get_telephone()}")
    print(f"Customer Number: {customer.get_customer_number()}")
    print(f"On Mailing List: {'Yes' if customer.get_on_mailing_list() else 'No'}")

if __name__ == "__main__":
    main()
# Out:
# Enter the customer's name: bob
# Enter the customer's address: 1234
# Enter the customer's telephone number: 12345
# Enter the customer number: 444
# Does the customer wish to be on the mailing list? (yes/no): yes
#
# Customer Details:
# Name: bob
# Address: 1234
# Telephone: 12345
# Customer Number: 444
# On Mailing List: Yes

# %% [markdown]
# here is a flowchart of that work
# +--------------------------+
# |         Start            |
# +--------------------------+
#            |
#            v
# +--------------------------+
# |   Input Customer Data    |
# | - Name                   |
# | - Address                |
# | - Telephone              |
# | - Customer Number        |
# | - Mailing List (yes/no)  |
# +--------------------------+         |
#            v
# +--------------------------+
# |  Create Customer Object  |
# |  with Input Data         |
# +--------------------------+
#            |
#            v
# +--------------------------+
# |   Display Customer Data  |
# | - Name                   |
# | - Address                |
# | - Telephone              |
# | - Customer Number        |
# | - Mailing List Status    |
# +--------------------------+
#            |
#            v
# +--------------------------+
# |           End            |
# +--------------------------+
